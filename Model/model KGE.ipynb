# %%
# !pip install pykeen
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pykeen in /usr/local/lib/python3.7/dist-packages (1.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pykeen) (4.64.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.3.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.7.3)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.12.1+cu113)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from pykeen) (6.0)
# Requirement already satisfied: docdata in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.0.3)
# Requirement already satisfied: more-click in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.1.1)
# Requirement already satisfied: rexmex in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.1.2)
# Requirement already satisfied: click-default-group in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pykeen) (2.23.0)
# Requirement already satisfied: optuna>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pykeen) (3.0.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.5.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from pykeen) (7.1.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from pykeen) (9.0.0)
# Requirement already satisfied: pystow>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.4.7)
# Requirement already satisfied: class-resolver>=0.3.9 in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.3.10)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.8.10)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pykeen) (0.0.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pykeen) (1.21.6)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (6.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (1.8.1)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (0.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (1.4.44)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (3.10.1)
# Requirement already satisfied: importlib-metadata<5.0.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (4.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna>=2.0.0->pykeen) (21.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.2.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (5.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna>=2.0.0->pykeen) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5.0.0->optuna>=2.0.0->pykeen) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna>=2.0.0->pykeen) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->pykeen) (2022.6)
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (from pystow>=0.1.5->pykeen) (0.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.0->pykeen) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.3.0->optuna>=2.0.0->pykeen) (2.0.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (3.5.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (3.5.2)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (2.4.2)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (0.5.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna>=2.0.0->pykeen) (5.11.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna>=2.0.0->pykeen) (22.1.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna>=2.0.0->pykeen) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna>=2.0.0->pykeen) (0.2.5)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->pykeen) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->pykeen) (0.8.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from dataclasses-json->pykeen) (3.19.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->pykeen) (0.4.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic>=1.5.0->optuna>=2.0.0->pykeen) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pykeen) (1.24.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from rexmex->pykeen) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rexmex->pykeen) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->rexmex->pykeen) (1.2.0)

# %%
import tensorflow as tf 
import pandas as pd
import pykeen
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load Dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Portfolio/Neo4j/dataset.csv')
dataset = dataset.drop(columns=['Unnamed: 0'])
dataset
# Out:
#                           start_node    relation  \
# 0           Manufacturing_employment  subClassOf
# 1              Frameworks_for_gender  subClassOf
# 2      has_Inclusive_decision_making      domain
# 3          Financial_services_access  subClassOf
# 4       has_Science_tech_cooperation      domain
# ...                              ...         ...
# 37898                        classic   SimilarTo
# 37899                      classical   SimilarTo
# 37900                     classified   SimilarTo
# 37901                     classified   SimilarTo
# 37902                         classy   SimilarTo
#
#                                     end_node
# 0                           Green_Indicators
# 1                           Green_Indicators
# 2      Peace_Justice_and_Strong_Institutions
# 3                           Green_Indicators
# 4                 Partnerships_for_The_Goals
# ...                                      ...
# 37898                                typical
# 37899                           neoclassical
# 37900                              eyes only
# 37901                              sensitive
# 37902                                stylish
#
# [37903 rows x 3 columns]

# %% [markdown]
# ## Spilt data

# %%
from pykeen.triples import TriplesFactory

# %%
tf = TriplesFactory.from_labeled_triples(
  dataset[["start_node", "relation", "end_node"]].values,
  create_inverse_triples=False,
  entity_to_id=None,
  relation_to_id=None,
  compact_id=False,
  filter_out_candidate_inverse_relations=True,
  metadata=None,
)

# %%
#spilt data
training, validation, testing = tf.split([.8, .1, .1])
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=4079143477
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [556, 3746, 3746]

# %%
validation
# Out:
# TriplesFactory(num_entities=39054, num_relations=17, num_triples=3746, inverse_triples=False)

# %%
testing
# Out:
# TriplesFactory(num_entities=39054, num_relations=17, num_triples=3746, inverse_triples=False)

# %%
training
# Out:
# TriplesFactory(num_entities=39054, num_relations=17, num_triples=29964, inverse_triples=False)

# %% [markdown]
# ## Model KGE

# %%
from pykeen.pipeline import pipeline
from pykeen.hpo import hpo_pipeline
from pykeen.models import TransE

from pykeen.evaluation import RankBasedEvaluator
from pykeen.models.predict import get_tail_prediction_df
from pykeen.models import predict
# from pykeen.ablation import ablation_pipeline
from torch.optim import Adam, SGD
from pykeen.training import SLCWATrainingLoop
# from pykeen.evaluation import LCWAEvaluationLoop

# %% [markdown]
# ### TransE

# %%
TransE = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='TransE',
    loss='softplus',
    model_kwargs=dict(embedding_dim=20),
    optimizer='Adam',
    optimizer_kwargs=dict(lr=0.01),
    training_kwargs=dict(num_epochs=60, use_tqdm_batch=False),
    evaluation_kwargs=dict(batch_size=128,use_tqdm=False),
    evaluator='RankBasedEvaluator',
    random_seed=1,
    device='gpu',
    # regularizer='LpRegularizer',
    # regularizer_kwargs=dict(p=3),
    # training_loop='slcwa',
    # stopper='early',
    # stopper_kwargs=dict(frequency=5, patience=2, relative_delta=0.002),
    # evaluation_loop='LCWAEvaluationLoop',
)
# Out:
# INFO:pykeen.pipeline.api:Using device: gpu
# /usr/local/lib/python3.7/dist-packages/pykeen/nn/representation.py:372: UserWarning: Directly use Embedding.max_id instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.max_id instead of num_embeddings.")
# Training epochs on cuda:0:   0%|          | 0/60 [00:00<?, ?epoch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.93s seconds

# %%
print('Hit@K : ', TransE.get_metric('hits@k'))
print('Mean Rank : ', TransE.get_metric('mr'))
print('Mean Reciprocal Rank : ', TransE.get_metric('mrr'))
# print('Adjusted Mean Rank : ', TransE.get_me
# Out:
# Hit@K :  0.09329951948745328
# Mean Rank :  15844.818359375
# Mean Reciprocal Rank :  0.04002795038666244

# %% [markdown]
# #### predict model

# %%
# tail prediction

df = get_tail_prediction_df(
    model=TransE.model,
    head_label="Manufacturing_employment",
    relation_label="subClassOf",
    triples_factory=TransE.training,
    add_novelties=False,
)

print(df.head(5))
# Out:
#      tail_id                tail_label     score
# 832      832  Manufacturing_employment -0.676553
# 785      785          Green_Indicators -1.158750
# 702      702           Child_mortality -1.258308
# 735      735          Energy_intensity -1.354527
# 726      726    Disaster_deaths_injury -1.358621

# %%
# Score all triples (memory intensive)
predictions_df = predict.get_all_prediction_df(TransE.model, triples_factory=TransE.training)
# Out:
# WARNING:pykeen.models.predict:_predict is an expensive operation, involving 25928653572 score evaluations.
# WARNING:pykeen.models.predict:Not providing k to score_all_triples entails huge memory requirements for reasonably-sized knowledge graphs.

# %%
# Score top K triples (computationally expensive)
top_k_predictions_df = predict.get_all_prediction_df(TransE.model, k=3, triples_factory=testing)
# Out:
# WARNING:pykeen.models.predict:_predict is an expensive operation, involving 25928653572 score evaluations.
# scoring:   0%|          | 0.00/664k [00:00<?, ?batch/s]

# %%
top_k_predictions_df
# Out:
#    head_id                    head_label  relation_id relation_label  tail_id  \
# 0    35805                     stromboli           12          label    35805
# 1    28457               native language           12          label    28457
# 2    38090  very potent chemicals in use           12          label    38090
#
#                      tail_label     score  in_training
# 0                     stromboli -0.093675        False
# 1               native language -0.093675        False
# 2  very potent chemicals in use -0.093675        False

# %%
# Score a given list of triples
score_df = predict.predict_triples_df(
    model=TransE.model,
    triples=[("Sustainable_Development_Goals", "member", "Zero_Hunger"),
             ("Zero_Hunger", "subClassOf", "Sustainable_Development_Goals"),
             ("Air_pollution_deaths", "label", "Air_pollution_deaths")
             ],
    triples_factory=TransE.training,
)

# %%
# # Evaluate your model with not only testing triples,
# # but also filter on validation triples
# results = evaluator.evaluate(
#     model=TransE.model,
#     mapped_triples= testing.mapped_triples,
#     batch_size=1024,
#     # additional_filter_triples=[
#     #     training.mapped_triples,
#     #     validation.mapped_triples,
#     # ],
# )

# %% [markdown]
# ### RotatE

# %%
RotatE = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='RotatE',
    loss='softplus',
    model_kwargs=dict(embedding_dim=20),
    optimizer='Adam',
    optimizer_kwargs=dict(lr=0.01),
    training_kwargs=dict(num_epochs=60, use_tqdm_batch=False),
    evaluation_kwargs=dict(batch_size=128,use_tqdm=False),
    evaluator='RankBasedEvaluator',
    random_seed=1,
    device='gpu',
)

print('Hit@K : ', RotatE.get_metric('hits@k'))
print('Mean Rank : ', RotatE.get_metric('mr'))
print('Mean Reciprocal Rank : ', RotatE.get_metric('mrr'))
# Out:
# INFO:pykeen.pipeline.api:Using device: gpu
# /usr/local/lib/python3.7/dist-packages/pykeen/nn/representation.py:372: UserWarning: Directly use Embedding.max_id instead of num_embeddings.
#   warnings.warn(f"Directly use {self.__class__.__name__}.max_id instead of num_embeddings.")
# Training epochs on cuda:0:   0%|          | 0/60 [00:00<?, ?epoch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.18s seconds
# Hit@K :  0.0597971169247197
# Mean Rank :  13252.73046875
# Mean Reciprocal Rank :  0.04274922466125325

# %% [markdown]
# ### ComplEx

# %%
ComplEx = pipeline(
    training=training,
    testing=testing,
    validation=validation,
    model='ComplEx',
    loss='softplus',
    model_kwargs=dict(embedding_dim=20),
    optimizer='Adam',
    optimizer_kwargs=dict(lr=0.01),
    training_kwargs=dict(num_epochs=60, use_tqdm_batch=False),
    evaluation_kwargs=dict(batch_size=128,use_tqdm=False),
    evaluator='RankBasedEvaluator',
    random_seed=1,
    device='gpu',
)

print('Hit@K : ', ComplEx.get_metric('hits@k'))
print('Mean Rank : ', ComplEx.get_metric('mr'))
print('Mean Reciprocal Rank : ', ComplEx.get_metric('mrr'))
# Out:
# INFO:pykeen.pipeline.api:Using device: gpu
# Training epochs on cuda:0:   0%|          | 0/60 [00:00<?, ?epoch/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.08s seconds
# Hit@K :  0.0
# Mean Rank :  19259.185546875
# Mean Reciprocal Rank :  0.00025428717076169874
